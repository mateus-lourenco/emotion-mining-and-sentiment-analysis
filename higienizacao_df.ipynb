# %% [markdown]
# # **Extração e Análise de Sentimentos em Letras de músicas do Forró**

# %% [markdown]
# ## NLP (Natural Language Processing)
# > É o processo pelo qual tentamos fazer com que um sistema de computador compreenda, analise e extraia a linguagem humana, muitas vezes com texto bruto..

# %%
import pandas as pd

# %%
df = pd.read_csv('./lyrics.csv', sep=';', encoding="utf-8")
#print(f'Quantidade de músicas: { df.id.count() }')
df.head()
# Out:
#    id                 title               artist                   composer  \
# 0   1      Não Se Esquecerá  Forrozão Tropykália                 Carlinhos.
# 1   2      Planeta de Cores  Forrozão Tropykália         CARLINHOS GABRIEL.
# 2   3  Enquanto Houver Amor  Forrozão Tropykália                 Dj Samuca.
# 3   4    Pronta Pra Te Amar  Forrozão Tropykália  Cristian Lima / Ivo Lima.
# 4   5          Saudade Mata  Forrozão Tropykália                        NaN
#
#                           album  year  \
# 0  Emoção Incomparável - Vol. 9     0
# 1  Emoção Incomparável - Vol. 9     0
# 2  Emoção Incomparável - Vol. 9     0
# 3  Emoção Incomparável - Vol. 9     0
# 4  Emoção Incomparável - Vol. 9     0
#
#                                                lyric
# 0  Sei que poderá levar um tempo Sei que poderá d...
# 1  Ei Vou deixar como está Vai ser mais uma histó...
# 2  Estou só sem você aqui A saudade me sufoca E m...
# 3  Meu amor porque foi embora Logo agora que eu t...
# 4  Saudade mata  Quando agente sente Que o amor d...

# %% [markdown]
# # Limpeza dos dados

# %% [markdown]
# 1. Remoção dos títulos das músicas que contenham os caracteres '()'

# %%
df['title'].replace("\((.*?)\)", '', regex=True, inplace=True)

# %% [markdown]
# 2. Remoção das músicas duplicadas a partir do título

# %%
df['title'] = df['title'].str.lower()
df['title'] = df['title'].str.strip()

titles = [i for i in df['title']]

duplicates = [i for i in titles if titles.count(i) > 1]
print(f'Quantidade de músicas duplicatas: {len(duplicates)}')
# Out:
# Quantidade de músicas duplicatas: 3484

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
df = df[~df['title'].isin(duplicates)]
print(f'Quantidade de músicas após remoção das duplicatas: {df.id.count()}')
# Out:
# Quantidade de músicas após remoção das duplicatas: 9921

# %% [markdown]
# 3. Remoção das músicas sem data

# %%
df = df[df['year'] > 0]

print(f'Quantidade de músicas com data: {df.id.count()}')
# Out:
# Quantidade de músicas com data: 8176

# %% [markdown]
# 4. Remoção dos registros sem letras

# %%
df = df[~df['lyric'].isnull()]
df['lyric'].count()
# Out:
# 8133

# %% [markdown]
# ## Criando bases de treino e teste

# %% [markdown]
# 1. Base de Treino

# %%
limit = int(df['id'].count() * (80/100)) + 1
train_df = df.head(limit)
train_df.to_csv('./lyrics_train.csv', index=False)

# %% [markdown]
# 2. Base de Teste

# %%
limit = int(df['id'].count() * (20/100))
train_df = df.head(limit)
train_df.to_csv('./lyrics_test.csv', index=False)
